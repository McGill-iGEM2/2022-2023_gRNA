# %%
import pandas as pd

# %%
df = pd.read_table('d75759ae-3040-4b99-9a90-b691fa0d497c.rna_seq.augmented_star_gene_counts.tsv')

# %%
df = df.reset_index(drop=False)

# %%
new_header = df.iloc[0] 
df = df[1:] 
df.columns = new_header

# %%
df
# Out:
# 0                 gene_id   gene_name       gene_type unstranded  \
# 1              N_unmapped         NaN             NaN     995738
# 2          N_multimapping         NaN             NaN   11219660
# 3             N_noFeature         NaN             NaN   39107931
# 4             N_ambiguous         NaN             NaN    4836046
# 5      ENSG00000000003.15      TSPAN6  protein_coding       1698
# ...                   ...         ...             ...        ...
# 60660   ENSG00000288669.1  AC008763.4  protein_coding          2
# 60661   ENSG00000288670.1  AL592295.6          lncRNA        291
# 60662   ENSG00000288671.1  AC006486.3  protein_coding          0
# 60663   ENSG00000288674.1  AL391628.1  protein_coding          7
# 60664   ENSG00000288675.1  AP006621.6  protein_coding          4
#
# 0     stranded_first stranded_second tpm_unstranded fpkm_unstranded  \
# 1             995738          995738            NaN             NaN
# ...
